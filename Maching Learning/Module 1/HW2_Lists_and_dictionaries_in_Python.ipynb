# %% [markdown]
# **1. Списки - базові операції**
#
# Створіть список температур за тиждень (у градусах Цельсія) з назвою
# `temperatures` і значеннями [22, 25, 19, 23, 26, 20, 21, 22].
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть перший елемент
# - Виведіть останній елемент
# - Додайте температуру 24
# - Видаліть температуру 19
# - Виведіть довжину списку
# - Обчисліть суму всіх температур
# - Знайдіть максимальну температуру

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]

print(f"Перший елемент списку: {temperatures[0]}")
print(f"Останній елемент списку: {temperatures[-1]}")
# Out:
# Перший елемент списку: 22
# Останній елемент списку: 22

# %%
temperatures.append(24) # додати температуру 24
temperatures
# Out:
# [22, 25, 19, 23, 26, 20, 21, 22, 24]

# %%
temperatures.remove(19) # видалити температуру 19
temperatures
# Out:
# [22, 25, 23, 26, 20, 21, 22, 24]

# %%
print(f"Довижна списку: {len(temperatures)}")
print(f"Сума всіх температур: {sum(temperatures)}")
print(f"Максимальна температура: {max(temperatures)}")
# Out:
# Довижна списку: 8
# Сума всіх температур: 183
# Максимальна температура: 26

# %% [markdown]
# **2. Словники - базові операції**
#
# Створіть словник про себе, який містить ключі `name`, `age`, `city` і значення, які відповідають вашему імені, віку і місту (можна вставити будь-які значення, не обовʼязково свої).
#
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Виведіть значення ключа "name"
# - Змініть значення ключа "age" на 21
# - Додайте новий ключ "hobby" зі значенням "programming"
# - Виведіть всі ключі
# - Виведіть всі значення

# %%
about_me = {
    "name": "Марія",
    "age": 19,
    "city": "Kyiv"
}
about_me
# Out:
# {'name': 'Марія', 'age': 19, 'city': 'Kyiv'}

# %%
print(f"Виведення значення ключа 'name': {about_me['name']}")
# Out:
# Виведення значення ключа 'name': Марія

# %%
about_me["age"] = 21
print(f"Вік після оновлення: {about_me.get('age')}")
# Out:
# Вік після оновлення: 21

# %%
about_me["hobby"] = "programming"
about_me
# Out:
# {'name': 'Марія', 'age': 21, 'city': 'Kyiv', 'hobby': 'programming'}

# %%
print(about_me.keys()) # виведення всіх ключів
print(about_me.values()) # виведення всіх значень
# Out:
# dict_keys(['name', 'age', 'city', 'hobby'])
# dict_values(['Марія', 21, 'Kyiv', 'programming'])
