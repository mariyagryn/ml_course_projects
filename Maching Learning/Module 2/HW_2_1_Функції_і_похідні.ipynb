# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
x = sp.symbols('x')
f = 10 * x - 5
derivative_f = sp.diff(f, x)

# %%
print("Функція: f(x) =", f)
print("Похідна: f'(x) =", derivative_f)
# Out:
# Функція: f(x) = 10*x - 5
# Похідна: f'(x) = 10

# %%
x = np.linspace(0, 10, 100)
f = 10 * x - 5
df = 10 * np.ones_like(x)

plt.plot(x, f, label='f(x) = 10x - 5', color='blue')
plt.plot(x, df, label="f'(x) = 10", color='red')
plt.title("Графік функції та її похідної")
plt.xlabel("кількість годин")
plt.ylabel("оцінка")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# На графіку видно, що зі збільшенням кількості годин навчання оцінка зростає лінійно. Синя пряма описується функцією f(x)=10x−5, тобто кожна додаткова година підготовки збільшує прогнозовану оцінку на 10 балів. Це показує червона лінія — похідна f′(x)=10, яка є сталою.
#
# Наприклад, при x=5 прогнозована оцінка дорівнює 10*5−5=45, а при x=10: 95. Значення при x=0 дорівнює −5, але тут це лише математична модель, а не реальна оцінка.

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
x = sp.symbols('x')

f_sin = sp.sin(x)
f_ln = sp.ln(x)

derivative_f_sin = sp.diff(f_sin, x)
derivative_f_ln = sp.diff(f_ln, x)

# %%
print("Функція: f(x) =", f_sin)
print("Похідна: f'(x) =", derivative_f_sin)
# Out:
# Функція: f(x) = sin(x)
# Похідна: f'(x) = cos(x)

# %%
print("Функція: f(x) =", f_ln)
print("Похідна: f'(x) =", derivative_f_ln)
# Out:
# Функція: f(x) = log(x)
# Похідна: f'(x) = 1/x

# %%
x_sin = np.linspace (0, 2 * np.pi, 100)
f_sin = np.sin(x_sin)
df_sin = np.cos(x_sin)

plt.plot(x_sin, f_sin, label='f(x) = sin(x)', color='blue')
plt.plot(x_sin, df_sin, label="f'(x) = cos(x)", color='green')
plt.title("Графік функції sin(x) та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
x_ln = np.linspace(0.1, 5, 100)
f_ln = np.log(x_ln)
df_ln = 1 / x_ln
plt.plot(x_ln, f_ln, label='f(x) = ln(x)', color='blue')
plt.plot(x_ln, df_ln, label="f'(x) = 1/x", color='green')
plt.title("Графік функції ln(x) та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
x = sp.symbols('x')
f = x**2 - 5*x + 1
derivative_f = sp.diff(f, x)
print("Функція: f(x) =", f)
print("Похідна: f'(x) =", derivative_f)
# Out:
# Функція: f(x) = x**2 - 5*x + 1
# Похідна: f'(x) = 2*x - 5

# %%
x = np.linspace(0, 100, 100)
f = x**2 - 5*x + 1
df = 2*x - 5

plt.plot(x, f, label='f(x) = x^2 - 5x + 1', color='blue')
plt.plot(x, df, label="f'(x) = 2x - 5", color='green')
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()
