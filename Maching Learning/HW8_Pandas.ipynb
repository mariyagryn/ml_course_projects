# %% [markdown]
# У цьому домашньому завданні ми будемо працювати з набором даних Tips. Нижче інформація про нього.
#
# **Про датасет:**
#
# Tips - це датасет, який містить інформацію про рахунки та чайові в ресторані.
#
# **Колонки датасету:**
# - `total_bill` - загальна сума рахунку (долари)
# - `tip` - розмір чайових (долари)
# - `sex` - стать відвідувача (Male/Female)
# - `smoker` - чи курить (Yes/No)
# - `day` - день тижня (Thur/Fri/Sat/Sun)
# - `time` - час відвідування (Lunch/Dinner)
# - `size` - розмір групи (кількість людей)
#
# **Джерело:** Оригінальні дані зібрані в одному з американських ресторанів у 1990-х роках. Скачати і переглянути набір даних можна тут: https://www.kaggle.com/datasets/sakshisatre/tips-dataset
#
# А також ми вже вивантажили файл з даними і завантажили вам у Матеріали до цього модуля.

# %% [markdown]
# **1. Завантаження та огляд**
#
# Завантажте датасет Tips (Чайові) з файла у матеріалах `tips.csv`.
#
# Виведіть (кожен пункт оцінюється в 0.5 бала):
# - Перші 5 рядків
# - Розмір датасету (shape)
# - Назви всіх колонок
# - Інформацію про типи даних (info)

# %%
import pandas as pd

# %%
df = pd.read_csv('tip.csv')

# %%
print("=== 1. Перші 5 рядків ===")
display(df.head())

print("=== 2. Розмір датасету (shape) ===")
display(df.shape)

print("=== 3. Назви колонок ===")
display(df.columns)

print("=== 4. Інформація про типи даних ===")
df.info()
# Out:
# === 1. Перші 5 рядків ===
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# === 2. Розмір датасету (shape) ===
# (244, 7)
# === 3. Назви колонок ===
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# === 4. Інформація про типи даних ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# **2. Базова вибірка даних**
#
# Виберіть та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Колонку `total_bill` (загальний рахунок)
# - Колонки `total_bill` та `tip` (чайові) разом
# - Перші 10 рядків
# - Рядок з індексом 5

# %%
print("=== 1. Колонка total_bill ===")
display(df["total_bill"])

print("=== 2. Колонки total_bill та tip ===")
display(df[["total_bill", "tip"]])

print("=== 3. Перші 10 рядків ===")
display(df.head(10)) # або df.iloc[:10, :])

print("=== 4. Рядок з індексом 5 ===")
display(df.loc[5])   # або df.iloc[5]
# Out:
# === 1. Колонка total_bill ===
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64
# === 2. Колонки total_bill та tip ===
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]
# === 3. Перші 10 рядків ===
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
# === 4. Рядок з індексом 5 ===
# total_bill     25.29
# tip             4.71
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 5, dtype: object

# %% [markdown]
# **3. Фільтрація даних**
#
# Відфільтруйте повний набір даних та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Всі рахунки більше 20 доларів (`total_bill > 20`)
# - Всі відвідувачі-жінки (`sex == 'Female'`)
# - Рахунки на вечерю (`time == 'Dinner'`)
# - Рахунки на вечерю з сумою чеку більше 30 доларів
#
# Для виведення результатів фільтрації:
# - зберегти результат у окрему змінну
# - показати кількість записів у відфільтрованому наборі
# - вивести перші 5 записів відфільтрованого набору.

# %%
bills_over_20 = df[df['total_bill'] > 20]

print("Кількість рахунків > 20 доларів:", len(bills_over_20))
print("Перші 5 рядків:")
display(bills_over_20.head())
# Out:
# Кількість рахунків > 20 доларів: 97
# Перші 5 рядків:
#    total_bill   tip     sex smoker  day    time  size
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
female_visitors = df[df['sex'] == 'Female']

print("Кількість відвідувачів-жінок:", len(female_visitors))
print("Перші 5 рядків:")
display(female_visitors.head())
# Out:
# Кількість відвідувачів-жінок: 87
# Перші 5 рядків:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
dinner_bills = df[df['time'] == 'Dinner']

print("Кількість рахунків на вечерю:", len(dinner_bills))
print("Перші 5 рядків:")
display(dinner_bills.head())
# Out:
# Кількість рахунків на вечерю: 176
# Перші 5 рядків:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dinner_bills = df[(df['time'] == 'Dinner') & (df['total_bill'] > 30)]

print("Кількість вечірніх рахунків > 30:", len(dinner_bills))
print("Перші 5 рядків:")
display(dinner_bills.head())
# Out:
# Кількість вечірніх рахунків > 30: 27
# Перші 5 рядків:
#     total_bill   tip     sex smoker  day    time  size
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 39       31.27  5.00    Male     No  Sat  Dinner     3
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4

# %% [markdown]
# ---
#
# **4. Описова статистика**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній розмір рахунку на всьому наборі даних
# - Максимальні чайові
# - Кількість пропущених значень у всіх колонках
# - Скільки в наборі даних рахунків за обіди і за вечері

# %%
average = df['total_bill'].mean()
print(f'Середній розмір рахунку: {average.round(2)}')

max = df['tip'].max()
print(f'Максимальні чайові: {max}')

empty = df.isnull().sum().sum()
print(f'Кількість пропущених значень у всіх колонках: {empty}')

meal_counts = df["time"].value_counts()
print("\nКількість рахунків за обід та вечерю:")
print(meal_counts)
# Out:
# Середній розмір рахунку: 19.79
# Максимальні чайові: 10.0
# Кількість пропущених значень у всіх колонках: 0
#
# Кількість рахунків за обід та вечерю:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# **5. Статистика із групуванням**
#
# Обчисліть (кожен пункт оцінюється в 0.5 бала):
# - Середній рахунок за статтю (groupby `sex`)
# - Середні чайові за днем тижня (groupby `day`)
# - Скільки відвідувачів у кожен день

# %%
avg_bill_by_sex = df.groupby("sex")["total_bill"].mean()
print("Середній рахунок за статтю:")
print(avg_bill_by_sex.round(2), "\n")

avg_tip_by_day = df.groupby("day")["tip"].mean()
print("Середні чайові за днем тижня:")
print(avg_tip_by_day.round(2), "\n")

visitors_per_day = df.groupby("day")["size"].sum()
print("Кількість відвідувачів у кожен день:")
print(visitors_per_day)
# Out:
# Середній рахунок за статтю:
# sex
# Female    18.06
# Male      20.74
# Name: total_bill, dtype: float64
#
# Середні чайові за днем тижня:
# day
# Fri     2.73
# Sat     2.99
# Sun     3.26
# Thur    2.77
# Name: tip, dtype: float64
#
# Кількість відвідувачів у кожен день:
# day
# Fri      40
# Sat     219
# Sun     216
# Thur    152
# Name: size, dtype: int64

# %% [markdown]
# ---
#
# **6. Створення нової колонки**
#
# Створіть нову колонку `tip_percentage` - відсоток чайових від загальної суми рахунку.
# Виведіть перші 10 рядків з новою колонкою.

# %%
df["tip_percentage"] = df["tip"] / df["total_bill"] * 100
df["tip_percentage"] = df["tip_percentage"].round(2)

print("Перші 10 рядків з новою колонкою tip_percentage:")
display(df.head(10))
# Out:
# Перші 10 рядків з новою колонкою tip_percentage:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2            5.94
# 1       10.34  1.66    Male     No  Sun  Dinner     3           16.05
# 2       21.01  3.50    Male     No  Sun  Dinner     3           16.66
# 3       23.68  3.31    Male     No  Sun  Dinner     2           13.98
# 4       24.59  3.61  Female     No  Sun  Dinner     4           14.68
# 5       25.29  4.71    Male     No  Sun  Dinner     4           18.62
# 6        8.77  2.00    Male     No  Sun  Dinner     2           22.81
# 7       26.88  3.12    Male     No  Sun  Dinner     4           11.61
# 8       15.04  1.96    Male     No  Sun  Dinner     2           13.03
# 9       14.78  3.23    Male     No  Sun  Dinner     2           21.85

# %% [markdown]
# ---
#
# **7. Сортування**
#
# Відсортуйте датасет і виведіть результат сортування в кожному випадку окремо (кожен пункт оцінюється в 0.5 бала):
# - За розміром рахунку (зростання)
# - За чайовими (спадання)
#
# Додатково виведіть топ-5 найбільших чайових використовуючи метод `nlargest`.

# %%
sorted_by_bill = df.sort_values(by="total_bill", ascending=True)

print("Сортування за total_bill (зростання):")
display(sorted_by_bill.head(10))
# Out:
# Сортування за total_bill (зростання):
#      total_bill   tip     sex smoker   day    time  size  tip_percentage
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1           32.57
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2           17.39
# 111        7.25  1.00  Female     No   Sat  Dinner     1           13.79
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2           71.03
# 149        7.51  2.00    Male     No  Thur   Lunch     2           26.63
# 195        7.56  1.44    Male     No  Thur   Lunch     2           19.05
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2           18.60
# 145        8.35  1.50  Female     No  Thur   Lunch     2           17.96
# 135        8.51  1.25  Female     No  Thur   Lunch     2           14.69
# 126        8.52  1.48    Male     No  Thur   Lunch     2           17.37

# %%
sorted_by_tip = df.sort_values(by="tip", ascending=False)

print("\nСортування за tip (спадання):")
display(sorted_by_tip.head(10))
# Out:
# Сортування за tip (спадання):
#      total_bill    tip     sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3           19.68
# 212       48.33   9.00    Male     No   Sat  Dinner     4           18.62
# 23        39.42   7.58    Male     No   Sat  Dinner     4           19.23
# 59        48.27   6.73    Male     No   Sat  Dinner     4           13.94
# 141       34.30   6.70    Male     No  Thur   Lunch     6           19.53
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4           28.05
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3           23.07
# 47        32.40   6.00    Male     No   Sun  Dinner     4           18.52
# 239       29.03   5.92    Male     No   Sat  Dinner     3           20.39
# 88        24.71   5.85    Male     No  Thur   Lunch     2           23.67

# %%
top5_tips = df.nlargest(5, "tip")

print("\nТоп-5 найбільших чайових:")
display(top5_tips)
# Out:
# Топ-5 найбільших чайових:
#      total_bill    tip   sex smoker   day    time  size  tip_percentage
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3           19.68
# 212       48.33   9.00  Male     No   Sat  Dinner     4           18.62
# 23        39.42   7.58  Male     No   Sat  Dinner     4           19.23
# 59        48.27   6.73  Male     No   Sat  Dinner     4           13.94
# 141       34.30   6.70  Male     No  Thur   Lunch     6           19.53
