# %% [markdown]
# **1. Функція з параметром**
#
# Створіть функцію `show_menu()`, яка приймає перелік страв, наприклад ['Піца', 'Паста', 'Салат'] і виводить меню ресторану в наступному вигляді:
# ```
# === МЕНЮ ===
# 1. Піца
# 2. Паста
# 3. Салат
# =============
# ```
#
# Викличте цю функцію на списку ["Суп грибний", "Котлета по-київськи", "Лимонад"].

# %%
def show_menu(dishes):
    print("=== МЕНЮ ===")
    for i, dish in enumerate(dishes):
        print(f"{i+1}. {dish}")
    print("============")

menu = ["Суп грибний", "Котлета по-київськи", "Лимонад"]
show_menu(menu)
# Out:
# === МЕНЮ ===
# 1. Суп грибний
# 2. Котлета по-київськи
# 3. Лимонад
# ============

# %% [markdown]
# ---
#
# **2. Функція з параметром**
#
# Створіть функцію `print_square(n)`, яка виводить квадрат числа.
#
# Наприклад: `print_square(5)` → "Квадрат числа 5 = 25"
#
# Викличте її з різними числами.

# %%
def print_square(n):
    square = n ** 2
    print(f"Квадрат числа {n} = {square}")

numbers = [0, 1, 5, 8, 11, 14, 17, 19, -5, -3]

for num in numbers:
    print_square(num)
# Out:
# Квадрат числа 0 = 0
# Квадрат числа 1 = 1
# Квадрат числа 5 = 25
# Квадрат числа 8 = 64
# Квадрат числа 11 = 121
# Квадрат числа 14 = 196
# Квадрат числа 17 = 289
# Квадрат числа 19 = 361
# Квадрат числа -5 = 25
# Квадрат числа -3 = 9

# %% [markdown]
# ---
#
# **3. Функція з поверненням значення**
#
# Створіть функцію `multiply(a, b)`, яка повертає добуток двох чисел.
#
# Викличте функцію на власноруч заданих значеннях та виведіть результат.

# %%
def multiply(a, b):
    """
    Повертає добуток двох чисел a і b
    """
    return a * b


# задані значення
result1 = multiply(12, 5)
result2 = multiply(3, 7)

print(f"Добуток 12 і 5 = {result1}")
print(f"Добуток 3 і 7 = {result2}")
# Out:
# Добуток 12 і 5 = 60
# Добуток 3 і 7 = 21

# %% [markdown]
# ---
#
# **4. Функція пошуку максимумального значення**
#
# Створіть функцію `find_max(numbers)`, яка:
# - Приймає список чисел
# - Повертає найбільше число в списку
#
# Протестуйте на списку `[15, 42, 8, 23, 56, 19]`.

# %%
def find_max(numbers):
    """
    Повертає найбільше число зі списку numbers
    """
    return max(numbers)


numbers = [15, 42, 8, 23, 56, 19]

result = find_max(numbers)
print(f"Найбільше число в списку: {result}")




# функція через lambda
find_max = lambda numbers: max(numbers)
numbers = [15, 42, 8, 23, 56, 19]
result = find_max(numbers)
print(f"Найбільше число в списку: {result}")
# Out:
# Найбільше число в списку: 56
# Найбільше число в списку: 56

# %% [markdown]
# ---
#
# **5. Функція з умовами**
#
# Створіть функцію `check_grade(grade)`, яка:
# - Приймає оцінку (число)
# - Повертає "Здав" якщо grade >= 60
# - Повертає "Не здав" якщо grade < 60
#
# Протестуйте на різних оцінках.

# %%
def check_grade(grade):
    if grade >= 60:
        return "Здав"
    else:
        return "Не здав"

for g in [45, 60, 72, 100]:
    result = check_grade(g)
    print(f"Оцінка {g}: {result}")
# Out:
# Оцінка 45: Не здав
# Оцінка 60: Здав
# Оцінка 72: Здав
# Оцінка 100: Здав
